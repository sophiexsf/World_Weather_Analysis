# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

from citipy import citipy
import time
from datetime import datetime

import pandas as pd

# %%
import numpy as np

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lat = np.random.uniform(-90, 90, size=2000)
lng = np.random.uniform(-180, 180, size=2000)
coordinates = zip(lat, lng)

# %%
# Get the nearest city using the citipy module.

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

cities
# Out:
# ['yellowknife',
#  'iqaluit',
#  'nador',
#  'mamakan',
#  'kushima',
#  'chokurdakh',
#  'saint george',
#  'ushuaia',
#  'port elizabeth',
#  'sheregesh',
#  'lebu',
#  'punta arenas',
#  'kapaa',
#  'albany',
#  'provideniya',
#  'pisco',
#  'caravelas',
#  'taolanaro',
#  'talcahuano',
#  'gazli',
#  'puerto ayora',
#  'hobart',
#  'bow island',
#  'amderma',
#  'rawannawi',
#  'derzhavinsk',
#  'visnes',
#  'zhigansk',
#  'zharkent',
#  'port lincoln',
#  'barrow',
#  'avarua',
#  'illoqqortoormiut',
#  'pemangkat',
#  'souillac',
#  'ribeira grande',
#  'port alfred',
#  'timmins',
#  'khani',
#  'porto novo',
#  'ilulissat',
#  'castro',
#  'butaritari',
#  'hithadhoo',
#  'taicheng',
#  'makakilo city',
#  'manturovo',
#  'cassilandia',
#  'vaini',
#  'mehamn',
#  'port blair',
#  'saint-pierre',
#  'mataura',
#  'bredasdorp',
#  'menongue',
#  'cape town',
#  'georgetown',
#  'mercedes',
#  'bluff',
#  'noumea',
#  'andenes',
#  'hilo',
#  'cidreira',
#  'luderitz',
#  'nemuro',
#  'puerto madryn',
#  'mahebourg',
#  'vyartsilya',
#  'belushya guba',
#  'chuy',
#  'council bluffs',
#  'saint-philippe',
#  'kawana waters',
#  'mar del plata',
#  'rikitea',
#  'plettenberg bay',
#  'matameye',
#  'busselton',
#  'okhotsk',
#  'kholodnyy',
#  'le port',
#  'ligayan',
#  'guozhen',
#  'hermanus',
#  'lompoc',
#  'paradwip',
#  'college',
#  'luau',
#  'kavaratti',
#  'hasaki',
#  'gat',
#  'price',
#  'saskylakh',
#  'katsuura',
#  'kumluca',
#  'tuktoyaktuk',
#  'fandriana',
#  'cayenne',
#  'thompson',
#  'barsovo',
#  'vestmannaeyjar',
#  'fayaoue',
#  'muros',
#  'leningradskiy',
#  'jamestown',
#  'arriaga',
#  'sao jose da coroa grande',
#  'lukh',
#  'lynn haven',
#  'esperance',
#  'nabire',
#  'riyadh',
#  'marcona',
#  'tsihombe',
#  'umzimvubu',
#  'taltal',
#  'ola',
#  'tatsuno',
#  'airai',
#  'port-gentil',
#  'lampazos de naranjo',
#  'norman wells',
#  'nanortalik',
#  'vila velha',
#  'fortuna',
#  'guerrero negro',
#  'zatoka',
#  'mbuji-mayi',
#  'arona',
#  'cervo',
#  'jinchang',
#  'kuala terengganu',
#  'ondorhaan',
#  'tasiilaq',
#  'new norfolk',
#  'pokosnoye',
#  'nuevo progreso',
#  'sehithwa',
#  'bambous virieux',
#  'kaeo',
#  'severo-kurilsk',
#  'vila franca do campo',
#  'coquimbo',
#  'grindavik',
#  'babanusah',
#  'dingle',
#  'namibe',
#  'asino',
#  'port shepstone',
#  'arraial do cabo',
#  'el balyana',
#  'brownwood',
#  'hokitika',
#  'mrirt',
#  'saryshagan',
#  'husavik',
#  'prainha',
#  'troutdale',
#  'atuona',
#  'esso',
#  'izhma',
#  'cabo san lucas',
#  'langenburg',
#  'angoche',
#  'cherskiy',
#  'sitka',
#  'qaanaaq',
#  'raymond',
#  'zilair',
#  'biak',
#  'oistins',
#  'clyde river',
#  'popova',
#  'san cristobal',
#  'mayo',
#  'puerto escondido',
#  'miracatu',
#  'tumen',
#  'itarema',
#  'lanzhou',
#  'tautira',
#  'la ronge',
#  'monte patria',
#  'khatanga',
#  'klaksvik',
#  'upernavik',
#  'nikolskoye',
#  'staunton',
#  'kasane',
#  'diamantino',
#  'palmer',
#  'tuatapere',
#  'payo',
#  'teya',
#  'acarau',
#  'barentsburg',
#  'krasnoselkup',
#  'penzance',
#  'buy',
#  'tabou',
#  'tumannyy',
#  'mount gambier',
#  'torbay',
#  'trentola-ducenta',
#  'talnakh',
#  'zhanakorgan',
#  'mackenzie',
#  'alghero',
#  'saint anthony',
#  'mys shmidta',
#  'tilichiki',
#  'vallenar',
#  'banff',
#  'gizo',
#  'hofn',
#  'geraldton',
#  'nybro',
#  'portland',
#  'phan thiet',
#  'laguna',
#  'melilla',
#  'funadhoo',
#  'east london',
#  'alice springs',
#  'puerto del rosario',
#  'stornoway',
#  'nyurba',
#  'ostrovnoy',
#  'ponta do sol',
#  'lesozavodsk',
#  'vilyuysk',
#  'kodiak',
#  'gladstone',
#  'faya',
#  'samalaeulu',
#  'narsaq',
#  'pevek',
#  'dunedin',
#  'sentyabrskiy',
#  'iquitos',
#  'saldanha',
#  'ulaanbaatar',
#  'flin flon',
#  'chilca',
#  'hami',
#  'kasongo-lunda',
#  'yendi',
#  'pyshchug',
#  'rolim de moura',
#  'bardiyah',
#  'ketchikan',
#  'slonim',
#  'serenje',
#  'belmonte',
#  'havoysund',
#  'yemtsa',
#  'frontera',
#  'buala',
#  'ancud',
#  'vaitupu',
#  'makat',
#  'whitehorse',
#  'cabedelo',
#  'astaneh-ye ashrafiyeh',
#  'korla',
#  'paita',
#  'bom jesus',
#  'sicamous',
#  'velasco ibarra',
#  'koumac',
#  'akyab',
#  'vanavara',
#  'carnarvon',
#  'ahipara',
#  'carballo',
#  'dikson',
#  'saint-augustin',
#  'sobradinho',
#  'kingman',
#  'kahului',
#  'balkanabat',
#  'tubruq',
#  'tranas',
#  'general roca',
#  'tarko-sale',
#  'warqla',
#  'ulladulla',
#  'razole',
#  'burgeo',
#  'mareeba',
#  'eyl',
#  'vao',
#  'pokhara',
#  'alotau',
#  'thurso',
#  'antalaha',
#  'liverpool',
#  'turbat',
#  'longyearbyen',
#  'flinders',
#  'victoria',
#  'alofi',
#  'artyk',
#  'bolungarvik',
#  'boshnyakovo',
#  'louisbourg',
#  'liberal',
#  'domoni',
#  'mount pleasant',
#  'benguela',
#  'yerbogachen',
#  'afmadu',
#  'verkh-usugli',
#  'san vicente',
#  'diffa',
#  'kainantu',
#  'victor harbor',
#  'feijo',
#  'hambantota',
#  'hanna',
#  'sotara',
#  'sao filipe',
#  'kruisfontein',
#  'pokrovskoye',
#  'bailen',
#  'lagoa',
#  'emporia',
#  'olkhovatka',
#  'ayabaca',
#  'barentu',
#  'bathsheba',
#  'divnomorskoye',
#  'zhangye',
#  'natal',
#  'champerico',
#  'port hardy',
#  'guarapari',
#  'muroto',
#  'barda',
#  'broome',
#  'aviles',
#  'bontang',
#  'aklavik',
#  'galgani',
#  'yuancheng',
#  'hovd',
#  'lac du bonnet',
#  'cockburn town',
#  'rathdrum',
#  'collipulli',
#  'kalabo',
#  'coahuayana',
#  'tottori',
#  'moree',
#  'satitoa',
#  'praid',
#  'igrim',
#  'balabac',
#  'khash',
#  'arica',
#  'el faiyum',
#  'roald',
#  'yablonovo',
#  'cabanas',
#  'lorengau',
#  'nizhneyansk',
#  'the valley',
#  'lynchburg',
#  'moses lake',
#  'grand river south east',
#  'notre-dame-du-lac',
#  'batagay-alyta',
#  'harper',
#  'mabaruma',
#  'bath',
#  'fairlie',
#  'temir',
#  'ogaminana',
#  'asau',
#  'dakar',
#  'tomatlan',
#  'bria',
#  'kenai',
#  'rawson',
#  'naryan-mar',
#  'saleaula',
#  'kargil',
#  'samusu',
#  'sault sainte marie',
#  'qandala',
#  'hobyo',
#  'ishim',
#  'moryakovskiy zaton',
#  'listvyanskiy',
#  'ngama',
#  'faanui',
#  'erzin',
#  'skjervoy',
#  'walvis bay',
#  'mazamari',
#  'santa cruz',
#  'kampong cham',
#  'codrington',
#  'padang',
#  'conceicao do araguaia',
#  'labuhan',
#  'nome',
#  'abu samrah',
#  'petropavlovsk-kamchatskiy',
#  'milazzo',
#  'kita',
#  'issenye',
#  'puerto leguizamo',
#  'kralendijk',
#  'asasa',
#  'ekhabi',
#  'kyaikto',
#  'fairbanks',
#  'ariquemes',
#  'linxia',
#  'dzhebariki-khaya',
#  'aksha',
#  'tiksi',
#  'clonakilty',
#  'stykkisholmur',
#  'roma',
#  'warrnambool',
#  'grants pass',
#  'lavrentiya',
#  'solenzo',
#  'alpena',
#  'rio grande',
#  'kokkola',
#  'salalah',
#  'sena madureira',
#  'richards bay',
#  'nouadhibou',
#  'comodoro rivadavia',
#  'san pedro',
#  'quatre cocos',
#  'agirish',
#  'srikakulam',
#  'san joaquin',
#  'tidore',
#  'khokhlovo',
#  'foix',
#  'ayr',
#  'lafiagi',
#  'mashhad',
#  'paamiut',
#  'terra santa',
#  'lishui',
#  'antofagasta',
#  'waipawa',
#  'palitana',
#  'san jose',
#  'haines junction',
#  'dwarka',
#  'marawi',
#  'oktyabrskoye',
#  'leh',
#  'qabis',
#  'boianu mare',
#  'watertown',
#  'brae',
#  'ratnagiri',
#  'necochea',
#  'karamea',
#  'vostok',
#  'owando',
#  'nalut',
#  'jiddah',
#  'mitu',
#  'chapais',
#  'bethel',
#  'kamenskoye',
#  'barranco',
#  'sao gabriel da cachoeira',
#  'atambua',
#  'rosaryville',
#  'cape canaveral',
#  'singaparna',
#  'mahanje',
#  'manica',
#  'svetlyy',
#  'samarai',
#  'aplahoue',
#  'meulaboh',
#  'dien bien',
#  'mwense',
#  'tiznit',
#  'north bend',
#  'kapit',
#  'moron',
#  'raudeberg',
#  'tessalit',
#  'kirakira',
#  'tombouctou',
#  'phan rang',
#  'srednekolymsk',
#  'chabahar',
#  'coffs harbour',
#  'mantua',
#  'touros',
#  'huntsville',
#  'keetmanshoop',
#  'pimentel',
#  'avera',
#  'kununurra',
#  'raahe',
#  'sechura',
#  'vuktyl',
#  'sembe',
#  'abong mbang',
#  'hirara',
#  'monrovia',
#  'rairangpur',
#  'dudinka',
#  'kaseda',
#  'jijiang',
#  'ulaangom',
#  'nguiu',
#  'yulara',
#  'burnie',
#  'paris',
#  'huarmey',
#  'kastamonu',
#  'constitucion',
#  'deputatskiy',
#  'perth',
#  'preobrazheniye',
#  'palabuhanratu',
#  'barbar',
#  'novobirilyussy',
#  'rakhya',
#  'bilma',
#  'vieques',
#  'sioux lookout',
#  'soyo',
#  'aksu',
#  'batticaloa',
#  'minab',
#  'dongsheng',
#  'waingapu',
#  'medicine hat',
#  'broken hill',
#  'albanel',
#  'prince rupert',
#  'fraga',
#  'verkhnevilyuysk',
#  'kissidougou',
#  'madhipura',
#  'yumen',
#  'awjilah',
#  'mokhsogollokh',
#  'puerto colombia',
#  'lazaro cardenas',
#  'barcelona',
#  'fukue',
#  'sukpak',
#  'quzhou',
#  'kuche',
#  'yabelo',
#  'bodden town',
#  'kulhudhuffushi',
#  'goma',
#  'abnub',
#  'emerald',
#  'teguise',
#  'tianmen',
#  'ruteng',
#  'camacupa',
#  'konstantinovsk',
#  'harwich',
#  'wanning',
#  'mugango',
#  'havre-saint-pierre',
#  'rocha',
#  'oktyabrskiy',
#  'lixourion',
#  'nantucket',
#  'tadpatri',
#  'jeremoabo',
#  'chagda',
#  'lyuban',
#  'tambovka',
#  'pacific grove',
#  'tapejara',
#  'coihaique',
#  'linares',
#  'lima',
#  'kavieng',
#  'bargal',
#  'gannan',
#  'bonthe',
#  'magadan',
#  'durban',
#  'saryg-sep',
#  'itoman',
#  'sao gotardo',
#  'sikea',
#  'aldan',
#  'amnat charoen',
#  'puerto rondon',
#  'denpasar',
#  'veraval',
#  'san patricio',
#  'taoudenni',
#  'rio gallegos',
#  'haibowan',
#  'jammalamadugu',
#  'okha',
#  'douentza',
#  'khonuu',
#  'mahon',
#  'deep river',
#  'mtwara',
#  'esil',
#  'mangai',
#  'port macquarie',
#  'chapada dos guimaraes',
#  'san felipe',
#  'cap malheureux',
#  'stromness',
#  'praia',
#  'baykit',
#  'toora-khem',
#  'cap-aux-meules',
#  'mayumba',
#  'great yarmouth',
#  'auki',
#  'maniitsoq',
#  'adrar',
#  'basco',
#  'kieta',
#  'springdale',
#  'bulgan',
#  'bengkulu',
#  'ust-barguzin',
#  'kumba',
#  'tezu',
#  'dicabisagan',
#  'dawlatabad',
#  'atar',
#  'greenlaw',
#  'peniche',
#  'rayachoti',
#  'batagay',
#  'mandalgovi',
#  'chimbote',
#  'merauke',
#  'amos',
#  'montepuez',
#  'washington',
#  'sungaipenuh',
#  'pontal do parana',
#  'beringovskiy',
#  'worksop',
#  'kupang',
#  'naze',
#  'chegdomyn',
#  'santa cruz del norte',
#  'sorland',
#  'tawang',
#  'baturaja',
#  'portobelo',
#  'pittsburg',
#  'poya',
#  'andradina',
#  'bur gabo',
#  'polson',
#  'buta',
#  'dasoguz',
#  'puteyets',
#  'zyryanka',
#  'saint thomas mount',
#  'chiochis',
#  'nara',
#  'kaitangata',
#  'acari',
#  'candolim',
#  'road town',
#  'rorvik',
#  'flers',
#  'santa rosa',
#  'ossora',
#  'karmana',
#  'deh rawud',
#  'san quintin',
#  'honningsvag',
#  'khirkiya',
#  'daru',
#  'princesa isabel',
#  'manadhoo',
#  'vardo',
#  'fethiye',
#  'nelson bay',
#  'erenhot',
#  'waitati',
#  'shu',
#  'barra do garcas',
#  'hamilton',
#  'nehe',
#  'kankon',
#  'kankakee',
#  'domanivka',
#  'floro',
#  'ucluelet',
#  'caldwell',
#  'igarka',
#  'bossangoa',
#  'artvin',
#  'gimli',
#  'attawapiskat',
#  'bilibino',
#  'esna',
#  'mustasaari',
#  'puerto maldonado',
#  'severodvinsk',
#  'kondinskoye',
#  'santa isabel',
#  'tshikapa',
#  'zlobin',
#  'amahai',
#  'cam ranh',
#  'marzuq',
#  'san miguel de cauri',
#  'mityana',
#  'olafsvik',
#  'klyuchevskiy',
#  'rio de janeiro',
#  'thinadhoo',
#  'ixtapa',
#  'mastic beach',
#  'sola',
#  'cornwall',
#  'uzhur']

# %%
len(cities)
# Out:
# 737

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
city_data = []
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_weather_desc})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yellowknife
# Processing Record 2 of Set 1 | iqaluit
# Processing Record 3 of Set 1 | nador
# Processing Record 4 of Set 1 | mamakan
# Processing Record 5 of Set 1 | kushima
# Processing Record 6 of Set 1 | chokurdakh
# Processing Record 7 of Set 1 | saint george
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | port elizabeth
# Processing Record 10 of Set 1 | sheregesh
# Processing Record 11 of Set 1 | lebu
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | kapaa
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | provideniya
# Processing Record 16 of Set 1 | pisco
# Processing Record 17 of Set 1 | caravelas
# Processing Record 18 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 1 | talcahuano
# Processing Record 20 of Set 1 | gazli
# Processing Record 21 of Set 1 | puerto ayora
# Processing Record 22 of Set 1 | hobart
# Processing Record 23 of Set 1 | bow island
# Processing Record 24 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 1 | rawannawi
# City not found. Skipping...
# Processing Record 26 of Set 1 | derzhavinsk
# Processing Record 27 of Set 1 | visnes
# Processing Record 28 of Set 1 | zhigansk
# Processing Record 29 of Set 1 | zharkent
# Processing Record 30 of Set 1 | port lincoln
# Processing Record 31 of Set 1 | barrow
# Processing Record 32 of Set 1 | avarua
# Processing Record 33 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 1 | pemangkat
# Processing Record 35 of Set 1 | souillac
# Processing Record 36 of Set 1 | ribeira grande
# Processing Record 37 of Set 1 | port alfred
# Processing Record 38 of Set 1 | timmins
# Processing Record 39 of Set 1 | khani
# Processing Record 40 of Set 1 | porto novo
# Processing Record 41 of Set 1 | ilulissat
# Processing Record 42 of Set 1 | castro
# Processing Record 43 of Set 1 | butaritari
# Processing Record 44 of Set 1 | hithadhoo
# Processing Record 45 of Set 1 | taicheng
# Processing Record 46 of Set 1 | makakilo city
# Processing Record 47 of Set 1 | manturovo
# Processing Record 48 of Set 1 | cassilandia
# Processing Record 49 of Set 1 | vaini
# Processing Record 50 of Set 1 | mehamn
# Processing Record 1 of Set 2 | port blair
# Processing Record 2 of Set 2 | saint-pierre
# Processing Record 3 of Set 2 | mataura
# Processing Record 4 of Set 2 | bredasdorp
# Processing Record 5 of Set 2 | menongue
# Processing Record 6 of Set 2 | cape town
# Processing Record 7 of Set 2 | georgetown
# Processing Record 8 of Set 2 | mercedes
# Processing Record 9 of Set 2 | bluff
# Processing Record 10 of Set 2 | noumea
# Processing Record 11 of Set 2 | andenes
# Processing Record 12 of Set 2 | hilo
# Processing Record 13 of Set 2 | cidreira
# Processing Record 14 of Set 2 | luderitz
# Processing Record 15 of Set 2 | nemuro
# Processing Record 16 of Set 2 | puerto madryn
# Processing Record 17 of Set 2 | mahebourg
# Processing Record 18 of Set 2 | vyartsilya
# Processing Record 19 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 2 | chuy
# Processing Record 21 of Set 2 | council bluffs
# Processing Record 22 of Set 2 | saint-philippe
# Processing Record 23 of Set 2 | kawana waters
# City not found. Skipping...
# Processing Record 24 of Set 2 | mar del plata
# Processing Record 25 of Set 2 | rikitea
# Processing Record 26 of Set 2 | plettenberg bay
# Processing Record 27 of Set 2 | matameye
# City not found. Skipping...
# Processing Record 28 of Set 2 | busselton
# Processing Record 29 of Set 2 | okhotsk
# Processing Record 30 of Set 2 | kholodnyy
# Processing Record 31 of Set 2 | le port
# Processing Record 32 of Set 2 | ligayan
# Processing Record 33 of Set 2 | guozhen
# Processing Record 34 of Set 2 | hermanus
# Processing Record 35 of Set 2 | lompoc
# Processing Record 36 of Set 2 | paradwip
# City not found. Skipping...
# Processing Record 37 of Set 2 | college
# Processing Record 38 of Set 2 | luau
# Processing Record 39 of Set 2 | kavaratti
# Processing Record 40 of Set 2 | hasaki
# Processing Record 41 of Set 2 | gat
# Processing Record 42 of Set 2 | price
# Processing Record 43 of Set 2 | saskylakh
# Processing Record 44 of Set 2 | katsuura
# Processing Record 45 of Set 2 | kumluca
# Processing Record 46 of Set 2 | tuktoyaktuk
# Processing Record 47 of Set 2 | fandriana
# Processing Record 48 of Set 2 | cayenne
# Processing Record 49 of Set 2 | thompson
# Processing Record 50 of Set 2 | barsovo
# Processing Record 1 of Set 3 | vestmannaeyjar
# Processing Record 2 of Set 3 | fayaoue
# Processing Record 3 of Set 3 | muros
# Processing Record 4 of Set 3 | leningradskiy
# Processing Record 5 of Set 3 | jamestown
# Processing Record 6 of Set 3 | arriaga
# Processing Record 7 of Set 3 | sao jose da coroa grande
# Processing Record 8 of Set 3 | lukh
# Processing Record 9 of Set 3 | lynn haven
# Processing Record 10 of Set 3 | esperance
# Processing Record 11 of Set 3 | nabire
# Processing Record 12 of Set 3 | riyadh
# Processing Record 13 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 3 | taltal
# Processing Record 17 of Set 3 | ola
# Processing Record 18 of Set 3 | tatsuno
# Processing Record 19 of Set 3 | airai
# Processing Record 20 of Set 3 | port-gentil
# Processing Record 21 of Set 3 | lampazos de naranjo
# Processing Record 22 of Set 3 | norman wells
# Processing Record 23 of Set 3 | nanortalik
# Processing Record 24 of Set 3 | vila velha
# Processing Record 25 of Set 3 | fortuna
# Processing Record 26 of Set 3 | guerrero negro
# Processing Record 27 of Set 3 | zatoka
# Processing Record 28 of Set 3 | mbuji-mayi
# Processing Record 29 of Set 3 | arona
# Processing Record 30 of Set 3 | cervo
# Processing Record 31 of Set 3 | jinchang
# Processing Record 32 of Set 3 | kuala terengganu
# Processing Record 33 of Set 3 | ondorhaan
# City not found. Skipping...
# Processing Record 34 of Set 3 | tasiilaq
# Processing Record 35 of Set 3 | new norfolk
# Processing Record 36 of Set 3 | pokosnoye
# Processing Record 37 of Set 3 | nuevo progreso
# Processing Record 38 of Set 3 | sehithwa
# Processing Record 39 of Set 3 | bambous virieux
# Processing Record 40 of Set 3 | kaeo
# Processing Record 41 of Set 3 | severo-kurilsk
# Processing Record 42 of Set 3 | vila franca do campo
# Processing Record 43 of Set 3 | coquimbo
# Processing Record 44 of Set 3 | grindavik
# Processing Record 45 of Set 3 | babanusah
# City not found. Skipping...
# Processing Record 46 of Set 3 | dingle
# Processing Record 47 of Set 3 | namibe
# Processing Record 48 of Set 3 | asino
# Processing Record 49 of Set 3 | port shepstone
# Processing Record 50 of Set 3 | arraial do cabo
# Processing Record 1 of Set 4 | el balyana
# City not found. Skipping...
# Processing Record 2 of Set 4 | brownwood
# Processing Record 3 of Set 4 | hokitika
# Processing Record 4 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 5 of Set 4 | saryshagan
# City not found. Skipping...
# Processing Record 6 of Set 4 | husavik
# Processing Record 7 of Set 4 | prainha
# Processing Record 8 of Set 4 | troutdale
# Processing Record 9 of Set 4 | atuona
# Processing Record 10 of Set 4 | esso
# Processing Record 11 of Set 4 | izhma
# Processing Record 12 of Set 4 | cabo san lucas
# Processing Record 13 of Set 4 | langenburg
# Processing Record 14 of Set 4 | angoche
# Processing Record 15 of Set 4 | cherskiy
# Processing Record 16 of Set 4 | sitka
# Processing Record 17 of Set 4 | qaanaaq
# Processing Record 18 of Set 4 | raymond
# Processing Record 19 of Set 4 | zilair
# Processing Record 20 of Set 4 | biak
# Processing Record 21 of Set 4 | oistins
# Processing Record 22 of Set 4 | clyde river
# Processing Record 23 of Set 4 | popova
# Processing Record 24 of Set 4 | san cristobal
# Processing Record 25 of Set 4 | mayo
# Processing Record 26 of Set 4 | puerto escondido
# Processing Record 27 of Set 4 | miracatu
# Processing Record 28 of Set 4 | tumen
# Processing Record 29 of Set 4 | itarema
# Processing Record 30 of Set 4 | lanzhou
# Processing Record 31 of Set 4 | tautira
# Processing Record 32 of Set 4 | la ronge
# Processing Record 33 of Set 4 | monte patria
# Processing Record 34 of Set 4 | khatanga
# Processing Record 35 of Set 4 | klaksvik
# Processing Record 36 of Set 4 | upernavik
# Processing Record 37 of Set 4 | nikolskoye
# Processing Record 38 of Set 4 | staunton
# Processing Record 39 of Set 4 | kasane
# Processing Record 40 of Set 4 | diamantino
# Processing Record 41 of Set 4 | palmer
# Processing Record 42 of Set 4 | tuatapere
# Processing Record 43 of Set 4 | payo
# Processing Record 44 of Set 4 | teya
# Processing Record 45 of Set 4 | acarau
# Processing Record 46 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 4 | krasnoselkup
# Processing Record 48 of Set 4 | penzance
# Processing Record 49 of Set 4 | buy
# Processing Record 50 of Set 4 | tabou
# Processing Record 1 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 5 | mount gambier
# Processing Record 3 of Set 5 | torbay
# Processing Record 4 of Set 5 | trentola-ducenta
# Processing Record 5 of Set 5 | talnakh
# Processing Record 6 of Set 5 | zhanakorgan
# Processing Record 7 of Set 5 | mackenzie
# Processing Record 8 of Set 5 | alghero
# Processing Record 9 of Set 5 | saint anthony
# Processing Record 10 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 5 | tilichiki
# Processing Record 12 of Set 5 | vallenar
# Processing Record 13 of Set 5 | banff
# Processing Record 14 of Set 5 | gizo
# Processing Record 15 of Set 5 | hofn
# Processing Record 16 of Set 5 | geraldton
# Processing Record 17 of Set 5 | nybro
# Processing Record 18 of Set 5 | portland
# Processing Record 19 of Set 5 | phan thiet
# Processing Record 20 of Set 5 | laguna
# Processing Record 21 of Set 5 | melilla
# Processing Record 22 of Set 5 | funadhoo
# Processing Record 23 of Set 5 | east london
# Processing Record 24 of Set 5 | alice springs
# Processing Record 25 of Set 5 | puerto del rosario
# Processing Record 26 of Set 5 | stornoway
# Processing Record 27 of Set 5 | nyurba
# Processing Record 28 of Set 5 | ostrovnoy
# Processing Record 29 of Set 5 | ponta do sol
# Processing Record 30 of Set 5 | lesozavodsk
# Processing Record 31 of Set 5 | vilyuysk
# Processing Record 32 of Set 5 | kodiak
# Processing Record 33 of Set 5 | gladstone
# Processing Record 34 of Set 5 | faya
# Processing Record 35 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 36 of Set 5 | narsaq
# Processing Record 37 of Set 5 | pevek
# Processing Record 38 of Set 5 | dunedin
# Processing Record 39 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 5 | iquitos
# Processing Record 41 of Set 5 | saldanha
# Processing Record 42 of Set 5 | ulaanbaatar
# Processing Record 43 of Set 5 | flin flon
# Processing Record 44 of Set 5 | chilca
# Processing Record 45 of Set 5 | hami
# Processing Record 46 of Set 5 | kasongo-lunda
# Processing Record 47 of Set 5 | yendi
# Processing Record 48 of Set 5 | pyshchug
# Processing Record 49 of Set 5 | rolim de moura
# City not found. Skipping...
# Processing Record 50 of Set 5 | bardiyah
# Processing Record 1 of Set 6 | ketchikan
# Processing Record 2 of Set 6 | slonim
# Processing Record 3 of Set 6 | serenje
# Processing Record 4 of Set 6 | belmonte
# Processing Record 5 of Set 6 | havoysund
# Processing Record 6 of Set 6 | yemtsa
# Processing Record 7 of Set 6 | frontera
# Processing Record 8 of Set 6 | buala
# Processing Record 9 of Set 6 | ancud
# Processing Record 10 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 6 | makat
# Processing Record 12 of Set 6 | whitehorse
# Processing Record 13 of Set 6 | cabedelo
# Processing Record 14 of Set 6 | astaneh-ye ashrafiyeh
# Processing Record 15 of Set 6 | korla
# Processing Record 16 of Set 6 | paita
# Processing Record 17 of Set 6 | bom jesus
# Processing Record 18 of Set 6 | sicamous
# Processing Record 19 of Set 6 | velasco ibarra
# Processing Record 20 of Set 6 | koumac
# Processing Record 21 of Set 6 | akyab
# Processing Record 22 of Set 6 | vanavara
# Processing Record 23 of Set 6 | carnarvon
# Processing Record 24 of Set 6 | ahipara
# Processing Record 25 of Set 6 | carballo
# Processing Record 26 of Set 6 | dikson
# Processing Record 27 of Set 6 | saint-augustin
# Processing Record 28 of Set 6 | sobradinho
# Processing Record 29 of Set 6 | kingman
# Processing Record 30 of Set 6 | kahului
# Processing Record 31 of Set 6 | balkanabat
# Processing Record 32 of Set 6 | tubruq
# City not found. Skipping...
# Processing Record 33 of Set 6 | tranas
# Processing Record 34 of Set 6 | general roca
# Processing Record 35 of Set 6 | tarko-sale
# Processing Record 36 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 37 of Set 6 | ulladulla
# Processing Record 38 of Set 6 | razole
# Processing Record 39 of Set 6 | burgeo
# Processing Record 40 of Set 6 | mareeba
# Processing Record 41 of Set 6 | eyl
# Processing Record 42 of Set 6 | vao
# Processing Record 43 of Set 6 | pokhara
# Processing Record 44 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 45 of Set 6 | thurso
# Processing Record 46 of Set 6 | antalaha
# Processing Record 47 of Set 6 | liverpool
# Processing Record 48 of Set 6 | turbat
# Processing Record 49 of Set 6 | longyearbyen
# Processing Record 50 of Set 6 | flinders
# Processing Record 1 of Set 7 | victoria
# Processing Record 2 of Set 7 | alofi
# Processing Record 3 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 4 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 5 of Set 7 | boshnyakovo
# Processing Record 6 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 7 of Set 7 | liberal
# Processing Record 8 of Set 7 | domoni
# Processing Record 9 of Set 7 | mount pleasant
# Processing Record 10 of Set 7 | benguela
# Processing Record 11 of Set 7 | yerbogachen
# Processing Record 12 of Set 7 | afmadu
# City not found. Skipping...
# Processing Record 13 of Set 7 | verkh-usugli
# Processing Record 14 of Set 7 | san vicente
# Processing Record 15 of Set 7 | diffa
# Processing Record 16 of Set 7 | kainantu
# Processing Record 17 of Set 7 | victor harbor
# Processing Record 18 of Set 7 | feijo
# Processing Record 19 of Set 7 | hambantota
# Processing Record 20 of Set 7 | hanna
# Processing Record 21 of Set 7 | sotara
# City not found. Skipping...
# Processing Record 22 of Set 7 | sao filipe
# Processing Record 23 of Set 7 | kruisfontein
# Processing Record 24 of Set 7 | pokrovskoye
# Processing Record 25 of Set 7 | bailen
# Processing Record 26 of Set 7 | lagoa
# Processing Record 27 of Set 7 | emporia
# Processing Record 28 of Set 7 | olkhovatka
# Processing Record 29 of Set 7 | ayabaca
# Processing Record 30 of Set 7 | barentu
# Processing Record 31 of Set 7 | bathsheba
# Processing Record 32 of Set 7 | divnomorskoye
# Processing Record 33 of Set 7 | zhangye
# Processing Record 34 of Set 7 | natal
# Processing Record 35 of Set 7 | champerico
# Processing Record 36 of Set 7 | port hardy
# Processing Record 37 of Set 7 | guarapari
# Processing Record 38 of Set 7 | muroto
# Processing Record 39 of Set 7 | barda
# Processing Record 40 of Set 7 | broome
# Processing Record 41 of Set 7 | aviles
# Processing Record 42 of Set 7 | bontang
# Processing Record 43 of Set 7 | aklavik
# Processing Record 44 of Set 7 | galgani
# City not found. Skipping...
# Processing Record 45 of Set 7 | yuancheng
# Processing Record 46 of Set 7 | hovd
# Processing Record 47 of Set 7 | lac du bonnet
# Processing Record 48 of Set 7 | cockburn town
# Processing Record 49 of Set 7 | rathdrum
# Processing Record 50 of Set 7 | collipulli
# Processing Record 1 of Set 8 | kalabo
# Processing Record 2 of Set 8 | coahuayana
# Processing Record 3 of Set 8 | tottori
# Processing Record 4 of Set 8 | moree
# Processing Record 5 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 6 of Set 8 | praid
# Processing Record 7 of Set 8 | igrim
# Processing Record 8 of Set 8 | balabac
# Processing Record 9 of Set 8 | khash
# Processing Record 10 of Set 8 | arica
# Processing Record 11 of Set 8 | el faiyum
# City not found. Skipping...
# Processing Record 12 of Set 8 | roald
# Processing Record 13 of Set 8 | yablonovo
# Processing Record 14 of Set 8 | cabanas
# Processing Record 15 of Set 8 | lorengau
# Processing Record 16 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 8 | the valley
# Processing Record 18 of Set 8 | lynchburg
# Processing Record 19 of Set 8 | moses lake
# Processing Record 20 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 8 | notre-dame-du-lac
# Processing Record 22 of Set 8 | batagay-alyta
# Processing Record 23 of Set 8 | harper
# Processing Record 24 of Set 8 | mabaruma
# Processing Record 25 of Set 8 | bath
# Processing Record 26 of Set 8 | fairlie
# Processing Record 27 of Set 8 | temir
# Processing Record 28 of Set 8 | ogaminana
# Processing Record 29 of Set 8 | asau
# Processing Record 30 of Set 8 | dakar
# Processing Record 31 of Set 8 | tomatlan
# Processing Record 32 of Set 8 | bria
# Processing Record 33 of Set 8 | kenai
# Processing Record 34 of Set 8 | rawson
# Processing Record 35 of Set 8 | naryan-mar
# Processing Record 36 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 8 | kargil
# Processing Record 38 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 8 | sault sainte marie
# Processing Record 40 of Set 8 | qandala
# Processing Record 41 of Set 8 | hobyo
# Processing Record 42 of Set 8 | ishim
# Processing Record 43 of Set 8 | moryakovskiy zaton
# Processing Record 44 of Set 8 | listvyanskiy
# Processing Record 45 of Set 8 | ngama
# Processing Record 46 of Set 8 | faanui
# Processing Record 47 of Set 8 | erzin
# Processing Record 48 of Set 8 | skjervoy
# Processing Record 49 of Set 8 | walvis bay
# Processing Record 50 of Set 8 | mazamari
# Processing Record 1 of Set 9 | santa cruz
# Processing Record 2 of Set 9 | kampong cham
# Processing Record 3 of Set 9 | codrington
# Processing Record 4 of Set 9 | padang
# Processing Record 5 of Set 9 | conceicao do araguaia
# Processing Record 6 of Set 9 | labuhan
# Processing Record 7 of Set 9 | nome
# Processing Record 8 of Set 9 | abu samrah
# Processing Record 9 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 10 of Set 9 | milazzo
# Processing Record 11 of Set 9 | kita
# Processing Record 12 of Set 9 | issenye
# Processing Record 13 of Set 9 | puerto leguizamo
# Processing Record 14 of Set 9 | kralendijk
# Processing Record 15 of Set 9 | asasa
# Processing Record 16 of Set 9 | ekhabi
# Processing Record 17 of Set 9 | kyaikto
# Processing Record 18 of Set 9 | fairbanks
# Processing Record 19 of Set 9 | ariquemes
# Processing Record 20 of Set 9 | linxia
# Processing Record 21 of Set 9 | dzhebariki-khaya
# Processing Record 22 of Set 9 | aksha
# Processing Record 23 of Set 9 | tiksi
# Processing Record 24 of Set 9 | clonakilty
# Processing Record 25 of Set 9 | stykkisholmur
# Processing Record 26 of Set 9 | roma
# Processing Record 27 of Set 9 | warrnambool
# Processing Record 28 of Set 9 | grants pass
# Processing Record 29 of Set 9 | lavrentiya
# Processing Record 30 of Set 9 | solenzo
# Processing Record 31 of Set 9 | alpena
# Processing Record 32 of Set 9 | rio grande
# Processing Record 33 of Set 9 | kokkola
# Processing Record 34 of Set 9 | salalah
# Processing Record 35 of Set 9 | sena madureira
# Processing Record 36 of Set 9 | richards bay
# Processing Record 37 of Set 9 | nouadhibou
# Processing Record 38 of Set 9 | comodoro rivadavia
# Processing Record 39 of Set 9 | san pedro
# Processing Record 40 of Set 9 | quatre cocos
# Processing Record 41 of Set 9 | agirish
# Processing Record 42 of Set 9 | srikakulam
# Processing Record 43 of Set 9 | san joaquin
# Processing Record 44 of Set 9 | tidore
# City not found. Skipping...
# Processing Record 45 of Set 9 | khokhlovo
# Processing Record 46 of Set 9 | foix
# Processing Record 47 of Set 9 | ayr
# Processing Record 48 of Set 9 | lafiagi
# Processing Record 49 of Set 9 | mashhad
# Processing Record 50 of Set 9 | paamiut
# Processing Record 1 of Set 10 | terra santa
# Processing Record 2 of Set 10 | lishui
# Processing Record 3 of Set 10 | antofagasta
# Processing Record 4 of Set 10 | waipawa
# Processing Record 5 of Set 10 | palitana
# Processing Record 6 of Set 10 | san jose
# Processing Record 7 of Set 10 | haines junction
# Processing Record 8 of Set 10 | dwarka
# Processing Record 9 of Set 10 | marawi
# Processing Record 10 of Set 10 | oktyabrskoye
# Processing Record 11 of Set 10 | leh
# Processing Record 12 of Set 10 | qabis
# City not found. Skipping...
# Processing Record 13 of Set 10 | boianu mare
# Processing Record 14 of Set 10 | watertown
# Processing Record 15 of Set 10 | brae
# Processing Record 16 of Set 10 | ratnagiri
# Processing Record 17 of Set 10 | necochea
# Processing Record 18 of Set 10 | karamea
# City not found. Skipping...
# Processing Record 19 of Set 10 | vostok
# Processing Record 20 of Set 10 | owando
# Processing Record 21 of Set 10 | nalut
# Processing Record 22 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 23 of Set 10 | mitu
# Processing Record 24 of Set 10 | chapais
# Processing Record 25 of Set 10 | bethel
# Processing Record 26 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 27 of Set 10 | barranco
# Processing Record 28 of Set 10 | sao gabriel da cachoeira
# Processing Record 29 of Set 10 | atambua
# Processing Record 30 of Set 10 | rosaryville
# Processing Record 31 of Set 10 | cape canaveral
# Processing Record 32 of Set 10 | singaparna
# Processing Record 33 of Set 10 | mahanje
# Processing Record 34 of Set 10 | manica
# Processing Record 35 of Set 10 | svetlyy
# Processing Record 36 of Set 10 | samarai
# Processing Record 37 of Set 10 | aplahoue
# Processing Record 38 of Set 10 | meulaboh
# Processing Record 39 of Set 10 | dien bien
# City not found. Skipping...
# Processing Record 40 of Set 10 | mwense
# Processing Record 41 of Set 10 | tiznit
# Processing Record 42 of Set 10 | north bend
# Processing Record 43 of Set 10 | kapit
# Processing Record 44 of Set 10 | moron
# Processing Record 45 of Set 10 | raudeberg
# Processing Record 46 of Set 10 | tessalit
# Processing Record 47 of Set 10 | kirakira
# Processing Record 48 of Set 10 | tombouctou
# Processing Record 49 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 50 of Set 10 | srednekolymsk
# Processing Record 1 of Set 11 | chabahar
# Processing Record 2 of Set 11 | coffs harbour
# Processing Record 3 of Set 11 | mantua
# Processing Record 4 of Set 11 | touros
# Processing Record 5 of Set 11 | huntsville
# Processing Record 6 of Set 11 | keetmanshoop
# Processing Record 7 of Set 11 | pimentel
# Processing Record 8 of Set 11 | avera
# Processing Record 9 of Set 11 | kununurra
# Processing Record 10 of Set 11 | raahe
# Processing Record 11 of Set 11 | sechura
# Processing Record 12 of Set 11 | vuktyl
# Processing Record 13 of Set 11 | sembe
# Processing Record 14 of Set 11 | abong mbang
# Processing Record 15 of Set 11 | hirara
# Processing Record 16 of Set 11 | monrovia
# Processing Record 17 of Set 11 | rairangpur
# Processing Record 18 of Set 11 | dudinka
# Processing Record 19 of Set 11 | kaseda
# Processing Record 20 of Set 11 | jijiang
# Processing Record 21 of Set 11 | ulaangom
# Processing Record 22 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 23 of Set 11 | yulara
# Processing Record 24 of Set 11 | burnie
# Processing Record 25 of Set 11 | paris
# Processing Record 26 of Set 11 | huarmey
# Processing Record 27 of Set 11 | kastamonu
# Processing Record 28 of Set 11 | constitucion
# Processing Record 29 of Set 11 | deputatskiy
# Processing Record 30 of Set 11 | perth
# Processing Record 31 of Set 11 | preobrazheniye
# Processing Record 32 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 34 of Set 11 | novobirilyussy
# Processing Record 35 of Set 11 | rakhya
# City not found. Skipping...
# Processing Record 36 of Set 11 | bilma
# Processing Record 37 of Set 11 | vieques
# Processing Record 38 of Set 11 | sioux lookout
# Processing Record 39 of Set 11 | soyo
# Processing Record 40 of Set 11 | aksu
# Processing Record 41 of Set 11 | batticaloa
# Processing Record 42 of Set 11 | minab
# Processing Record 43 of Set 11 | dongsheng
# Processing Record 44 of Set 11 | waingapu
# Processing Record 45 of Set 11 | medicine hat
# Processing Record 46 of Set 11 | broken hill
# Processing Record 47 of Set 11 | albanel
# Processing Record 48 of Set 11 | prince rupert
# Processing Record 49 of Set 11 | fraga
# Processing Record 50 of Set 11 | verkhnevilyuysk
# Processing Record 1 of Set 12 | kissidougou
# Processing Record 2 of Set 12 | madhipura
# Processing Record 3 of Set 12 | yumen
# Processing Record 4 of Set 12 | awjilah
# Processing Record 5 of Set 12 | mokhsogollokh
# Processing Record 6 of Set 12 | puerto colombia
# Processing Record 7 of Set 12 | lazaro cardenas
# Processing Record 8 of Set 12 | barcelona
# Processing Record 9 of Set 12 | fukue
# Processing Record 10 of Set 12 | sukpak
# Processing Record 11 of Set 12 | quzhou
# Processing Record 12 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 13 of Set 12 | yabelo
# Processing Record 14 of Set 12 | bodden town
# Processing Record 15 of Set 12 | kulhudhuffushi
# Processing Record 16 of Set 12 | goma
# Processing Record 17 of Set 12 | abnub
# Processing Record 18 of Set 12 | emerald
# Processing Record 19 of Set 12 | teguise
# Processing Record 20 of Set 12 | tianmen
# Processing Record 21 of Set 12 | ruteng
# Processing Record 22 of Set 12 | camacupa
# Processing Record 23 of Set 12 | konstantinovsk
# Processing Record 24 of Set 12 | harwich
# Processing Record 25 of Set 12 | wanning
# Processing Record 26 of Set 12 | mugango
# Processing Record 27 of Set 12 | havre-saint-pierre
# Processing Record 28 of Set 12 | rocha
# Processing Record 29 of Set 12 | oktyabrskiy
# Processing Record 30 of Set 12 | lixourion
# Processing Record 31 of Set 12 | nantucket
# Processing Record 32 of Set 12 | tadpatri
# Processing Record 33 of Set 12 | jeremoabo
# Processing Record 34 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 35 of Set 12 | lyuban
# Processing Record 36 of Set 12 | tambovka
# Processing Record 37 of Set 12 | pacific grove
# Processing Record 38 of Set 12 | tapejara
# Processing Record 39 of Set 12 | coihaique
# Processing Record 40 of Set 12 | linares
# Processing Record 41 of Set 12 | lima
# Processing Record 42 of Set 12 | kavieng
# Processing Record 43 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 44 of Set 12 | gannan
# Processing Record 45 of Set 12 | bonthe
# Processing Record 46 of Set 12 | magadan
# Processing Record 47 of Set 12 | durban
# Processing Record 48 of Set 12 | saryg-sep
# Processing Record 49 of Set 12 | itoman
# Processing Record 50 of Set 12 | sao gotardo
# Processing Record 1 of Set 13 | sikea
# City not found. Skipping...
# Processing Record 2 of Set 13 | aldan
# Processing Record 3 of Set 13 | amnat charoen
# Processing Record 4 of Set 13 | puerto rondon
# Processing Record 5 of Set 13 | denpasar
# Processing Record 6 of Set 13 | veraval
# Processing Record 7 of Set 13 | san patricio
# Processing Record 8 of Set 13 | taoudenni
# Processing Record 9 of Set 13 | rio gallegos
# Processing Record 10 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 11 of Set 13 | jammalamadugu
# Processing Record 12 of Set 13 | okha
# Processing Record 13 of Set 13 | douentza
# Processing Record 14 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 15 of Set 13 | mahon
# Processing Record 16 of Set 13 | deep river
# Processing Record 17 of Set 13 | mtwara
# Processing Record 18 of Set 13 | esil
# Processing Record 19 of Set 13 | mangai
# Processing Record 20 of Set 13 | port macquarie
# Processing Record 21 of Set 13 | chapada dos guimaraes
# Processing Record 22 of Set 13 | san felipe
# Processing Record 23 of Set 13 | cap malheureux
# Processing Record 24 of Set 13 | stromness
# Processing Record 25 of Set 13 | praia
# Processing Record 26 of Set 13 | baykit
# Processing Record 27 of Set 13 | toora-khem
# Processing Record 28 of Set 13 | cap-aux-meules
# Processing Record 29 of Set 13 | mayumba
# Processing Record 30 of Set 13 | great yarmouth
# Processing Record 31 of Set 13 | auki
# Processing Record 32 of Set 13 | maniitsoq
# Processing Record 33 of Set 13 | adrar
# Processing Record 34 of Set 13 | basco
# Processing Record 35 of Set 13 | kieta
# Processing Record 36 of Set 13 | springdale
# Processing Record 37 of Set 13 | bulgan
# Processing Record 38 of Set 13 | bengkulu
# Processing Record 39 of Set 13 | ust-barguzin
# Processing Record 40 of Set 13 | kumba
# Processing Record 41 of Set 13 | tezu
# Processing Record 42 of Set 13 | dicabisagan
# Processing Record 43 of Set 13 | dawlatabad
# Processing Record 44 of Set 13 | atar
# Processing Record 45 of Set 13 | greenlaw
# Processing Record 46 of Set 13 | peniche
# Processing Record 47 of Set 13 | rayachoti
# Processing Record 48 of Set 13 | batagay
# Processing Record 49 of Set 13 | mandalgovi
# Processing Record 50 of Set 13 | chimbote
# Processing Record 1 of Set 14 | merauke
# Processing Record 2 of Set 14 | amos
# Processing Record 3 of Set 14 | montepuez
# Processing Record 4 of Set 14 | washington
# Processing Record 5 of Set 14 | sungaipenuh
# Processing Record 6 of Set 14 | pontal do parana
# Processing Record 7 of Set 14 | beringovskiy
# Processing Record 8 of Set 14 | worksop
# Processing Record 9 of Set 14 | kupang
# Processing Record 10 of Set 14 | naze
# Processing Record 11 of Set 14 | chegdomyn
# Processing Record 12 of Set 14 | santa cruz del norte
# Processing Record 13 of Set 14 | sorland
# Processing Record 14 of Set 14 | tawang
# Processing Record 15 of Set 14 | baturaja
# Processing Record 16 of Set 14 | portobelo
# Processing Record 17 of Set 14 | pittsburg
# Processing Record 18 of Set 14 | poya
# Processing Record 19 of Set 14 | andradina
# Processing Record 20 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 21 of Set 14 | polson
# Processing Record 22 of Set 14 | buta
# Processing Record 23 of Set 14 | dasoguz
# Processing Record 24 of Set 14 | puteyets
# Processing Record 25 of Set 14 | zyryanka
# Processing Record 26 of Set 14 | saint thomas mount
# Processing Record 27 of Set 14 | chiochis
# Processing Record 28 of Set 14 | nara
# Processing Record 29 of Set 14 | kaitangata
# Processing Record 30 of Set 14 | acari
# Processing Record 31 of Set 14 | candolim
# Processing Record 32 of Set 14 | road town
# Processing Record 33 of Set 14 | rorvik
# Processing Record 34 of Set 14 | flers
# Processing Record 35 of Set 14 | santa rosa
# Processing Record 36 of Set 14 | ossora
# Processing Record 37 of Set 14 | karmana
# City not found. Skipping...
# Processing Record 38 of Set 14 | deh rawud
# City not found. Skipping...
# Processing Record 39 of Set 14 | san quintin
# Processing Record 40 of Set 14 | honningsvag
# Processing Record 41 of Set 14 | khirkiya
# Processing Record 42 of Set 14 | daru
# Processing Record 43 of Set 14 | princesa isabel
# Processing Record 44 of Set 14 | manadhoo
# Processing Record 45 of Set 14 | vardo
# Processing Record 46 of Set 14 | fethiye
# Processing Record 47 of Set 14 | nelson bay
# Processing Record 48 of Set 14 | erenhot
# Processing Record 49 of Set 14 | waitati
# Processing Record 50 of Set 14 | shu
# Processing Record 1 of Set 15 | barra do garcas
# Processing Record 2 of Set 15 | hamilton
# Processing Record 3 of Set 15 | nehe
# Processing Record 4 of Set 15 | kankon
# Processing Record 5 of Set 15 | kankakee
# Processing Record 6 of Set 15 | domanivka
# Processing Record 7 of Set 15 | floro
# Processing Record 8 of Set 15 | ucluelet
# Processing Record 9 of Set 15 | caldwell
# Processing Record 10 of Set 15 | igarka
# Processing Record 11 of Set 15 | bossangoa
# Processing Record 12 of Set 15 | artvin
# Processing Record 13 of Set 15 | gimli
# Processing Record 14 of Set 15 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 15 | bilibino
# Processing Record 16 of Set 15 | esna
# Processing Record 17 of Set 15 | mustasaari
# Processing Record 18 of Set 15 | puerto maldonado
# Processing Record 19 of Set 15 | severodvinsk
# Processing Record 20 of Set 15 | kondinskoye
# Processing Record 21 of Set 15 | santa isabel
# Processing Record 22 of Set 15 | tshikapa
# Processing Record 23 of Set 15 | zlobin
# Processing Record 24 of Set 15 | amahai
# Processing Record 25 of Set 15 | cam ranh
# Processing Record 26 of Set 15 | marzuq
# Processing Record 27 of Set 15 | san miguel de cauri
# Processing Record 28 of Set 15 | mityana
# Processing Record 29 of Set 15 | olafsvik
# Processing Record 30 of Set 15 | klyuchevskiy
# Processing Record 31 of Set 15 | rio de janeiro
# Processing Record 32 of Set 15 | thinadhoo
# Processing Record 33 of Set 15 | ixtapa
# Processing Record 34 of Set 15 | mastic beach
# Processing Record 35 of Set 15 | sola
# Processing Record 36 of Set 15 | cornwall
# Processing Record 37 of Set 15 | uzhur
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[column_order]
city_data_df.head(10)
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0     Yellowknife      CA  2022-02-05 01:25:50  62.4560 -114.3525    -26.72
# 1         Iqaluit      CA  2022-02-05 01:29:23  63.7506  -68.5145    -16.87
# 2           Nador      MA  2022-02-05 01:29:23  35.1740   -2.9287     62.85
# 3         Mamakan      RU  2022-02-05 01:29:24  57.8161  114.0028      1.45
# 4         Kushima      JP  2022-02-05 01:29:24  31.4583  131.2333     44.64
# 5      Chokurdakh      RU  2022-02-05 01:26:28  70.6333  147.9167    -30.78
# 6    Saint George      US  2022-02-05 01:24:25  37.1041 -113.5841     48.79
# 7         Ushuaia      AR  2022-02-05 01:27:01 -54.8000  -68.3000     49.66
# 8  Port Elizabeth      ZA  2022-02-05 01:29:24 -33.9180   25.5701     68.09
# 9       Sheregesh      RU  2022-02-05 01:29:25  52.9209   87.9869     -1.03
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        80          75        3.00       broken clouds
# 1        52          75        5.75       broken clouds
# 2        39           0        9.22           clear sky
# 3        97         100        2.01     overcast clouds
# 4        57          19       12.55          few clouds
# 5       100          16        1.72          few clouds
# 6        21           0        8.05           clear sky
# 7        66           0       12.66           clear sky
# 8        82          75        4.61       broken clouds
# 9        99          87        2.80     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
